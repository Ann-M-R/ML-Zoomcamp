# %%
import numpy as np
import pandas as pd

# %%
frame = pd.read_csv('bank-full.csv', delimiter=';')

# %%
frame
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
frame.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
frame.columns = frame.columns.str.lower().str.replace(' ','_')

# %%
frame.columns = frame.columns.str.lower().str.replace(' ','_')
# Out:
# Index(['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'], dtype='object')

# %%
fields = ['age', 'job','marital','education','balance','housing','contact','day','month','duration','campaign','pdays','previous','poutcome','y']

# %%
df = frame[fields]

# %%
df
# Out:
#        age           job   marital  education  balance housing    contact  \
# 0       58    management   married   tertiary     2143     yes    unknown
# 1       44    technician    single  secondary       29     yes    unknown
# 2       33  entrepreneur   married  secondary        2     yes    unknown
# 3       47   blue-collar   married    unknown     1506     yes    unknown
# 4       33       unknown    single    unknown        1      no    unknown
# ...    ...           ...       ...        ...      ...     ...        ...
# 45206   51    technician   married   tertiary      825      no   cellular
# 45207   71       retired  divorced    primary     1729      no   cellular
# 45208   72       retired   married  secondary     5715      no   cellular
# 45209   57   blue-collar   married  secondary      668      no  telephone
# 45210   37  entrepreneur   married  secondary     2971      no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# balance       int64
# housing      object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
numerical = ['age', 'balance', 'day', 'duration', 'campaign','pdays','previous']

# %%
categorical = list(set(fields) - set(numerical))

# %%
categorical
# Out:
# ['education', 'job', 'month', 'contact', 'poutcome', 'housing', 'y', 'marital']

# %%
df[categorical]
# Out:
#        education           job month    contact poutcome housing    y  \
# 0       tertiary    management   may    unknown  unknown     yes   no
# 1      secondary    technician   may    unknown  unknown     yes   no
# 2      secondary  entrepreneur   may    unknown  unknown     yes   no
# 3        unknown   blue-collar   may    unknown  unknown     yes   no
# 4        unknown       unknown   may    unknown  unknown      no   no
# ...          ...           ...   ...        ...      ...     ...  ...
# 45206   tertiary    technician   nov   cellular  unknown      no  yes
# 45207    primary       retired   nov   cellular  unknown      no  yes
# 45208  secondary       retired   nov   cellular  success      no  yes
# 45209  secondary   blue-collar   nov  telephone  unknown      no   no
# 45210  secondary  entrepreneur   nov   cellular    other      no   no
#
#         marital
# 0       married
# 1        single
# 2       married
# 3       married
# 4        single
# ...         ...
# ...

# %%
for c in categorical:
    df[c] = df[c].str.lower().str.replace(' ','_')
# Out:
# C:\Users\Ann\AppData\Local\Temp\ipykernel_17120\3631486017.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = df[c].str.lower().str.replace(' ','_')

# %%
df
# Out:
#        age           job   marital  education  balance housing    contact  \
# 0       58    management   married   tertiary     2143     yes    unknown
# 1       44    technician    single  secondary       29     yes    unknown
# 2       33  entrepreneur   married  secondary        2     yes    unknown
# 3       47   blue-collar   married    unknown     1506     yes    unknown
# 4       33       unknown    single    unknown        1      no    unknown
# ...    ...           ...       ...        ...      ...     ...        ...
# 45206   51    technician   married   tertiary      825      no   cellular
# 45207   71       retired  divorced    primary     1729      no   cellular
# 45208   72       retired   married  secondary     5715      no   cellular
# 45209   57   blue-collar   married  secondary      668      no  telephone
# 45210   37  entrepreneur   married  secondary     2971      no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
#checking if nulls exist
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Question 1

# %%
df.education.mode()
# Out:
# 0    secondary
# Name: education, dtype: object

# %% [markdown]
# ### Question 2

# %%
df[numerical].corrwith(df.balance)
# Out:
# age         0.097783
# balance     1.000000
# day         0.004503
# duration    0.021560
# campaign   -0.014578
# pdays       0.003435
# previous    0.016674
# dtype: float64

# %%
print(f'option1 : {df['age'].corr(df['balance'])}')
print(f'option1 : {df['day'].corr(df['campaign'])}')
print(f'option1 : {df['day'].corr(df['pdays'])}')
print(f'option1 : {df['pdays'].corr(df['previous'])}')
# Out:
# option1 : 0.09778273937134752
# option1 : 0.16249021632619282
# option1 : -0.09304407377294048
# option1 : 0.45481963548050097

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation_matrix = df[numerical].corr()
print(correlation_matrix)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(5,5))  # Adjust the size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Show the plot
plt.show()

# %%
df.y.nunique()
df.y
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 45206    yes
# 45207    yes
# 45208    yes
# 45209     no
# 45210     no
# Name: y, Length: 45211, dtype: object

# %%
#encoding y
df.y = (df.y == 'no').astype(int)
# Out:
# C:\Users\Ann\AppData\Local\Temp\ipykernel_17120\462358472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.y = (df.y == 'no').astype(int)

# %%
df.y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 45206    0
# 45207    0
# 45208    0
# 45209    1
# 45210    1
# Name: y, Length: 45211, dtype: int64

# %%
#splitting the data
from sklearn.model_selection import train_test_split

# %%
train_test_split(df, test_size=0.2, random_state=42)
# Out:
# [       age          job   marital  education  balance housing   contact  day  \
#  3344    41  blue-collar   married    primary      849     yes   unknown   15
#  17965   49   technician   married    primary     1415     yes  cellular   30
#  18299   42       admin.   married  secondary     3842      no  cellular   31
#  10221   37   management    single   tertiary     -119     yes   unknown   11
#  32192   56  blue-collar   married    primary     3498      no  cellular   15
#  ...    ...          ...       ...        ...      ...     ...       ...  ...
#  11284   44    housemaid    single    primary     1059      no   unknown   18
#  44732   23      student    single   tertiary      508      no  cellular    8
#  38158   34   technician  divorced   tertiary     1317     yes  cellular   15
#  860     33      retired   married  secondary      165      no   unknown    7
#  15795   38  blue-collar   married    primary      -41     yes  cellular   21
#
# ...

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
len(df_full_train), len(df_test)
# Out:
# (36168, 9043)

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)
len(df_train), len(df_val)
# Out:
# (27126, 9042)

# %%
df_train = df_train.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)

# %%
df_test
# Out:
#       age          job   marital  education  balance housing   contact  day  \
# 0      40  blue-collar   married  secondary      580     yes   unknown   16
# 1      47     services    single  secondary     3644      no   unknown    9
# 2      25      student    single   tertiary      538     yes  cellular   20
# 3      42   management   married   tertiary     1773      no  cellular    9
# 4      56   management   married   tertiary      217      no  cellular   21
# ...   ...          ...       ...        ...      ...     ...       ...  ...
# 9038   47   management   married   tertiary     1890      no  cellular    8
# 9039   32  blue-collar    single  secondary      217     yes  cellular   15
# 9040   52       admin.  divorced  secondary        0     yes   unknown   26
# 9041   40       admin.  divorced  secondary      783     yes   unknown   16
# 9042   37   technician   married  secondary     2209      no   unknown   20
#
# ...

# %%
y_train = df_train.y.values
y_test = df_test.y.values
y_val = df_val.y.values

# %%
del df_train['y']
del df_test['y']
del df_val['y']

# %% [markdown]
# ### Question 3

# %%
from sklearn.metrics import mutual_info_score

# %%
categorical.remove('y')

# %%
categorical
# Out:
# ['education', 'job', 'month', 'contact', 'poutcome', 'housing', 'marital']

# %%
def mutual_info_churn_score(series):
    return mutual_info_score(series, df.y)

# %%
df[categorical].apply(mutual_info_churn_score)
# Out:
# education    0.002598
# job          0.008264
# month        0.024351
# contact      0.013627
# poutcome     0.029397
# housing      0.009654
# marital      0.002101
# dtype: float64

# %%
mi = df[categorical].apply(mutual_info_churn_score)
mi.sort_values(ascending = False)
# Out:
# poutcome     0.029397
# month        0.024351
# contact      0.013627
# housing      0.009654
# job          0.008264
# education    0.002598
# marital      0.002101
# dtype: float64

# %% [markdown]
# ### Question 4

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
from sklearn.linear_model import LogisticRegression

# %%
df_train
# Out:
#        age            job   marital  education  balance housing    contact  \
# 0       41     management   married   tertiary      676      no    unknown
# 1       25        student    single  secondary     1747     yes   cellular
# 2       38    blue-collar    single    primary        0     yes   cellular
# 3       49     management    single   tertiary     4465     yes   cellular
# 4       38  self-employed   married  secondary     1029     yes   cellular
# ...    ...            ...       ...        ...      ...     ...        ...
# 27121   56     management   married  secondary     1502      no  telephone
# 27122   46     unemployed  divorced    primary       23      no   cellular
# 27123   33    blue-collar   married  secondary     -130     yes   cellular
# 27124   38     management   married   tertiary        0     yes   cellular
# 27125   50     management   married    primary     1458      no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome
# ...

# %%
train_dicts =  df_train.to_dict(orient = 'records')

# %%
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
X_train.shape
# Out:
# (27126, 47)

# %%
val_dicts =  df_val[categorical + numerical].to_dict(orient = 'records')
X_val = dv.fit_transform(val_dicts)
X_val.shape
# Out:
# (9042, 47)

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
model.predict(X_train)
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y_pred = model.predict_proba(X_train)[:,1]  
churn_decision = (y_pred >= 0.5)
accuracy = (y_train == churn_decision.astype(int)).mean()
accuracy
# Out:
# np.float64(0.9024920740249207)

# %%
y_pred = model.predict_proba(X_val)[:,1]  
churn_decision = (y_pred >= 0.5)
df_val[churn_decision]
# Out:
#       age            job  marital  education  balance housing    contact  day  \
# 0      34         admin.   single  secondary     4447     yes   cellular   10
# 1      44       services  married  secondary     -395     yes   cellular    5
# 2      34    blue-collar  married    primary      -78     yes    unknown    9
# 3      43     technician   single  secondary      463     yes   cellular   17
# 4      38  self-employed   single   tertiary     1612     yes   cellular    8
# ...   ...            ...      ...        ...      ...     ...        ...  ...
# 9036   38     management  married   tertiary     2278     yes   cellular   13
# 9037   34    blue-collar  married  secondary     -185     yes    unknown   13
# 9038   58     technician  married   tertiary      855     yes  telephone   18
# 9039   38     technician   single  secondary    12926     yes    unknown    3
# 9041   34     management  married   tertiary      676      no   cellular    7
#
# ...

# %%
y_val
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
(y_val == churn_decision.astype(int)).mean()
# Out:
# np.float64(0.9023446140234461)

# %% [markdown]
# ### Question 5

# %%
fields_no_age = ['job','marital','education','balance','housing','contact','day','month','duration','campaign','pdays','previous','poutcome']

# %%
train_dicts =  df_train[fields_no_age].to_dict(orient = 'records')
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# array([[ 6.760e+02,  1.000e+00,  0.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 1.747e+03,  1.000e+00,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 0.000e+00,  1.000e+00,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        ...,
#        [-1.300e+02,  2.000e+00,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 0.000e+00,  1.000e+00,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 1.458e+03,  1.000e+00,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00]])

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_train)[:,1]  
churn_decision = (y_pred >= 0.5)
accuracy_without_age = (y_train == churn_decision.astype(int)).mean()
accuracy_without_age
# Out:
# np.float64(0.9014967190149672)

# %%
fields_no_bal = ['age','job','marital','education','housing','contact','day','month','duration','campaign','pdays','previous','poutcome']
train_dicts =  df_train[fields_no_bal].to_dict(orient = 'records')
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_train)[:,1]  
churn_decision = (y_pred >= 0.5)
accuracy_without_balance = (y_train == churn_decision.astype(int)).mean()
accuracy_without_balance
# Out:
# np.float64(0.902565804025658)

# %%
fields_no_mar = ['age','job','education','balance','housing','contact','day','month','duration','campaign','pdays','previous','poutcome']
train_dicts =  df_train[fields_no_mar].to_dict(orient = 'records')
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_train)[:,1]  
churn_decision = (y_pred >= 0.5)
accuracy_without_marital = (y_train == churn_decision.astype(int)).mean()
accuracy_without_marital
# Out:
# np.float64(0.9021602890216028)

# %%
fields_no_pre = ['age','job','marital','education','balance','housing','contact','day','month','duration','campaign','pdays','poutcome']
train_dicts =  df_train[fields_no_pre].to_dict(orient = 'records')
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict_proba(X_train)[:,1]  
churn_decision = (y_pred >= 0.5)
accuracy_without_previous = (y_train == churn_decision.astype(int)).mean()
accuracy_without_previous
# Out:
# np.float64(0.9025289390252894)

# %%
original_acc = 0.9023446140234461
differences = []
differences.append(abs(accuracy - accuracy_without_age))
differences
# print(f'{original_acc - accuracy_without_age}')
# print(f'{original_acc - accuracy_without_balance}')
# print(f'{original_acc - accuracy_without_marital}')
# print(f'{original_acc - accuracy_without_previous}')
# Out:
# [np.float64(0.0009953550099535136)]

# %%
differences.append(abs(accuracy - accuracy_without_balance))
differences.append(abs(accuracy - accuracy_without_marital))
differences.append(abs(accuracy - accuracy_without_previous))
differences
# Out:
# [np.float64(0.0009953550099535136),
#  np.float64(7.373000073729319e-05),
#  np.float64(0.00033178500331787486),
#  np.float64(3.6865000368702106e-05)]

# %%
np.min(differences)
# Out:
# np.float64(3.6865000368702106e-05)

# %% [markdown]
# ### Question 6

# %%
fields = ['age','job','marital','education','balance','housing','contact','day','month','duration','campaign','pdays','previous','poutcome']
train_dicts =  df_train[fields].to_dict(orient = 'records')
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)

for c in [0.01, 0.1, 1, 10, 100]:
    model = LogisticRegression(solver='liblinear', C=c , max_iter=1000, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict_proba(X_train)[:,1]  
    churn_decision = (y_pred >= 0.5)
    y_pred = model.predict_proba(X_val)[:,1]  
    churn_decision = (y_pred >= 0.5)
    df_val[churn_decision]
    acc = (y_val == churn_decision.astype(int)).mean()
    print(f'c is {c}, accuracy is {acc}')
# Out:
# c is 0.01, accuracy is 0.8984737889847378
# c is 0.1, accuracy is 0.9015704490157045
# c is 1, accuracy is 0.9023446140234461
# c is 10, accuracy is 0.902676399026764
# c is 100, accuracy is 0.9009068790090687
